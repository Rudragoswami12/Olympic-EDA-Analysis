# %% [markdown]
# # Olympics Dataset:-

# %% [markdown]
#  # 1.Medal count
#  # 2.Relationship between medal and Team
#  # 3.Sport Type
#  # 4.Age and Weight Analysis
#  # 5.Visualization Seasons and there Games
#  # 6.EDA
#  # 7.Bivariant Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rb = pd.read_csv(r"C:\Users\ASUS\Downloads\Olympic datasaet\athlete_events.csv")

# %%
rb
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
rb.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
rb.describe(include="all")
# Out:
#                    ID                  Name     Sex            Age  \
# count   271116.000000                271116  271116  261642.000000
# unique            NaN                134732       2            NaN
# top               NaN  Robert Tait McKenzie       M            NaN
# freq              NaN                    58  196594            NaN
# mean     68248.954396                   NaN     NaN      25.556898
# std      39022.286345                   NaN     NaN       6.393561
# min          1.000000                   NaN     NaN      10.000000
# 25%      34643.000000                   NaN     NaN      21.000000
# 50%      68205.000000                   NaN     NaN      24.000000
# 75%     102097.250000                   NaN     NaN      28.000000
# max     135571.000000                   NaN     NaN      97.000000
#
#                Height         Weight           Team     NOC        Games  \
# count   210945.000000  208241.000000         271116  271116       271116
# ...

# %%
#drop element used for removing the sex column in the bottom code

# %%
rb.drop(["Sex"],axis=1,inplace=True)

# %%
rb['Name'].isnull().sum()
# Out:
# 0

# %%
rb.dropna(how = 'any', inplace = True)
rb.isnull().sum()
# Out:
# ID        0
# Name      0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
rb.head(5)
# Out:
#     ID                      Name   Age  Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season    City       Sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
# 42  1948 Summer  1948  Summer  London  Gymnastics
# 44  1948 Summer  1948  Summer  London  Gymnastics
# 48  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# ...

# %%
rb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30181 entries, 40 to 271103
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      30181 non-null  int64
#  1   Name    30181 non-null  object
#  2   Age     30181 non-null  float64
#  3   Height  30181 non-null  float64
#  4   Weight  30181 non-null  float64
#  5   Team    30181 non-null  object
#  6   NOC     30181 non-null  object
#  7   Games   30181 non-null  object
#  8   Year    30181 non-null  int64
#  9   Season  30181 non-null  object
#  10  City    30181 non-null  object
#  11  Sport   30181 non-null  object
#  12  Event   30181 non-null  object
#  13  Medal   30181 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 3.5+ MB

# %%
rb.isnull().sum()
# Out:
# ID        0
# Name      0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
rb.head(5)
# Out:
#     ID                      Name   Age  Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season    City       Sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
# 42  1948 Summer  1948  Summer  London  Gymnastics
# 44  1948 Summer  1948  Summer  London  Gymnastics
# 48  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# ...

# %% [markdown]
# # DATA CLENING:-

# %%
rb.dtypes
# Out:
# ID          int64
# Name       object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
rb["Name"].unique()
# Out:
# array(['Juhamatti Tapio Aaltonen', 'Paavo Johannes Aaltonen',
#        'Kjetil Andr Aamodt', ..., 'Galina Ivanovna Zybina (-Fyodorova)',
#        'Bogusaw Zych', 'Olesya Nikolayevna Zykina'], dtype=object)

# %%
rb.drop("City",axis=1,inplace=True)

# %%
rb.head(5)
# Out:
#     ID                      Name   Age  Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season       Sport  \
# 40  2014 Winter  2014  Winter  Ice Hockey
# 41  1948 Summer  1948  Summer  Gymnastics
# 42  1948 Summer  1948  Summer  Gymnastics
# 44  1948 Summer  1948  Summer  Gymnastics
# 48  1948 Summer  1948  Summer  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# 44            Gymnastics Men's Horse Vault    Gold
# ...

# %%
rb.Height
# Out:
# 40        184.0
# 41        175.0
# 42        175.0
# 44        175.0
# 48        175.0
#           ...
# 271078    168.0
# 271080    168.0
# 271082    182.0
# 271102    171.0
# 271103    171.0
# Name: Height, Length: 30181, dtype: float64

# %%
rb['Height'].unique()
# Out:
# array([184., 175., 176., 189., 182., 198., 194., 165., 179., 180., 185.,
#        186., 181., 163., 190., 188., 187., 191., 170., 173., 169., 160.,
#        167., 202., 166., 159., 172., 161., 197., 192., 183., 171., 168.,
#        178., 148., 150., 158., 174., 200., 162., 164., 193., 147., 177.,
#        195., 154., 156., 201., 157., 207., 203., 155., 215., 152., 196.,
#        211., 204., 199., 139., 208., 142., 214., 153., 143., 210., 205.,
#        206., 223., 216., 149., 151., 209., 213., 144., 140., 146., 136.,
#        138., 145., 217., 218., 141., 212., 219., 220., 137.])

# %%
rb.isnull().sum()
# Out:
# ID        0
# Name      0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
rb_Height=lambda x: str(x).split('/')[0]
rb.Height=rb.Height.apply(rb_Height)
rb['Height'].head()
# Out:
# 40    184.0
# 41    175.0
# 42    175.0
# 44    175.0
# 48    175.0
# Name: Height, dtype: object

# %%
rb.head(5)
# Out:
#     ID                      Name   Age Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen  28.0  184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
#
#           Games  Year  Season       Sport  \
# 40  2014 Winter  2014  Winter  Ice Hockey
# 41  1948 Summer  1948  Summer  Gymnastics
# 42  1948 Summer  1948  Summer  Gymnastics
# 44  1948 Summer  1948  Summer  Gymnastics
# 48  1948 Summer  1948  Summer  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# 44            Gymnastics Men's Horse Vault    Gold
# ...

# %%
rb.dtypes
# Out:
# ID          int64
# Name       object
# Age       float64
# Height     object
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
rb.shape
# Out:
# (30181, 13)

# %%
rb.size
# Out:
# 392353

# %%
rb.describe()
# Out:
#                   ID           Age        Weight          Year
# count   30181.000000  30181.000000  30181.000000  30181.000000
# mean    70225.949604     25.429012     73.753554   1988.005964
# std     38839.720551      5.049684     15.004992     22.718451
# min        16.000000     13.000000     28.000000   1896.000000
# 25%     37494.000000     22.000000     63.000000   1976.000000
# 50%     69771.000000     25.000000     73.000000   1992.000000
# 75%    104111.000000     28.000000     83.000000   2006.000000
# max    135563.000000     66.000000    182.000000   2016.000000

# %%
rb.duplicated()
# Out:
# 40        False
# 41        False
# 42        False
# 44        False
# 48        False
#           ...
# 271078    False
# 271080    False
# 271082    False
# 271102    False
# 271103    False
# Length: 30181, dtype: bool

# %%
rb.head(5)
# Out:
#     ID                      Name   Age Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen  28.0  184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
#
#           Games  Year  Season       Sport  \
# 40  2014 Winter  2014  Winter  Ice Hockey
# 41  1948 Summer  1948  Summer  Gymnastics
# 42  1948 Summer  1948  Summer  Gymnastics
# 44  1948 Summer  1948  Summer  Gymnastics
# 48  1948 Summer  1948  Summer  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# 44            Gymnastics Men's Horse Vault    Gold
# ...

# %% [markdown]
# # DATA VISUALIZATION:-

# %% [markdown]
# # 1.Medal Count

# %%
plt.hist(rb['Medal'])
plt.xlabel('Medal Count',fontsize=30,color='b')
plt.ylabel('Frequency',fontsize=30,color='c')
font = {'family':'serif','color':'red','size':50}
plt.title('Medal Count Distribution',fontdict=font)
plt.show()

# %% [markdown]
# # 2.Relationship between medal and team

# %%
sns.scatterplot(x='Team', y='Medal', data=rb)
font = {'family':'serif','color':'green','size':30}
plt.title('Relationship Between Medal Count and Team',fontdict=font)
# Out:
# Text(0.5, 1.0, 'Relationship Between Medal Count and Team')

# %% [markdown]
# # 3.Sport Type:-

# %%
df = plt.subplots(figsize = (10, 5))
mylabels = ["Athletics", "Hockey", "Ice Hockey", "Rowing", "Swimming"]
rb['Sport'].value_counts().head(5).plot(kind = 'pie',labels = mylabels, autopct="%1.1f%%")
plt.legend(title = "Sports",loc='right')

# %% [markdown]
# # 4.Age and Weight Analyasis:-

# %%
sns.set(rc={'figure.figsize':(25,10)})
ax=sns.boxplot(x='Age', y ='Weight',data=rb)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15692\4063868744.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# [Text(0, 0, '13.0'),
#  Text(1, 0, '14.0'),
#  Text(2, 0, '15.0'),
#  Text(3, 0, '16.0'),
#  Text(4, 0, '17.0'),
#  Text(5, 0, '18.0'),
#  Text(6, 0, '19.0'),
#  Text(7, 0, '20.0'),
#  Text(8, 0, '21.0'),
#  Text(9, 0, '22.0'),
#  Text(10, 0, '23.0'),
#  Text(11, 0, '24.0'),
#  Text(12, 0, '25.0'),
#  Text(13, 0, '26.0'),
#  Text(14, 0, '27.0'),
#  Text(15, 0, '28.0'),
#  Text(16, 0, '29.0'),
#  Text(17, 0, '30.0'),
#  Text(18, 0, '31.0'),
#  Text(19, 0, '32.0'),
#  Text(20, 0, '33.0'),
#  Text(21, 0, '34.0'),
#  Text(22, 0, '35.0'),
#  Text(23, 0, '36.0'),
#  Text(24, 0, '37.0'),
#  Text(25, 0, '38.0'),
#  Text(26, 0, '39.0'),
#  Text(27, 0, '40.0'),
#  Text(28, 0, '41.0'),
#  Text(29, 0, '42.0'),
#  Text(30, 0, '43.0'),
# ...

# %% [markdown]
# # 5.Visualization Season and There Gsmes:-

# %%
plt.figure(figsize=(10,15))
sns.boxplot(x=rb['Season'], y=rb['Games'])
# Out:
# <Axes: xlabel='Season', ylabel='Games'>

# %% [markdown]
# # 6. EDA:-

# %%
rb.hist(figsize=(25,20),color = "g")
# Out:
# array([[<Axes: title={'center': 'ID'}>, <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Weight'}>,
#         <Axes: title={'center': 'Year'}>]], dtype=object)

# %%
rb.head(5)
# Out:
#     ID                      Name   Age Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen  28.0  184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen  28.0  175.0    64.0  Finland  FIN
#
#           Games  Year  Season       Sport  \
# 40  2014 Winter  2014  Winter  Ice Hockey
# 41  1948 Summer  1948  Summer  Gymnastics
# 42  1948 Summer  1948  Summer  Gymnastics
# 44  1948 Summer  1948  Summer  Gymnastics
# 48  1948 Summer  1948  Summer  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# 44            Gymnastics Men's Horse Vault    Gold
# ...

# %% [markdown]
# # 7.BIVARIANT ANALYSIS:-

# %%
sns.pairplot(rb)
